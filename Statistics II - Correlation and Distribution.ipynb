# %% [markdown]
# ### Quiz Sampling Method
# Lembaga Survey yang ada di Indonesia ingin melakukan survey terkait Pemilu Tahun 2019. Diketahui jumlah total populasi di Indonesia sebanyak 200jt orang. Dengan margin or error sebesar 0.5% , berapakah jumlah sample yang dibutuhkan.

# %%
N = 200000000
e = 0.5/100

# %%
slovin = round(N/(1+N*e**2))
slovin
# Out:
# 39992

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop(['Id'],1)
# Out:
# /var/folders/_v/w4n5bq8d4ln32c93xcpqrnxc0000gn/T/ipykernel_20482/3875106297.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(['Id'],1)

# %%
df.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# # Coefficient Correlation

# %%
df.corr() #untuk melihat seberapa besar korelasi antar table
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Positive Correlation(0.96)

# %%
plt.figure(figsize = (10,7))
sns.regplot(x='PetalWidthCm',y='PetalLengthCm',data = df)
plt.show()

# %% [markdown]
# ### Negative Correlation (-0.46)

# %%
plt.figure(figsize = (10,7))
sns.regplot(x='SepalWidthCm',y='PetalLengthCm',data = df)
sns.scatterplot(x='SepalWidthCm',y='PetalLengthCm',hue='Species',data = df)
plt.show()

# %% [markdown]
# ### Weak Correlation (0.11)

# %%
plt.figure(figsize = (10,7))
sns.regplot(x='SepalWidthCm',y='SepalLengthCm',data = df)
plt.show()

# %% [markdown]
# # Mengetahui Sebaran dari SepalLengthCm

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize = (10,7))
plt.hist(df['SepalLengthCm'])
plt.show()

# %% [markdown]
# # Mengubah Sebaran tidak Normal menjadi Sebaran Normal

# %% [markdown]
# ## Transformasi Logaritma Natural

# %%
x = np.log(df['SepalLengthCm'])

plt.figure(figsize = (10,7))
plt.hist(x)
plt.show()

# %% [markdown]
# ### Mengapa ada Tiga Puncak?

# %%
setosa = df[df['Species'] == 'Iris-setosa']
virginica = df[df['Species'] == 'Iris-virginica']
versicolor = df[df['Species'] == 'Iris-versicolor']

# %%
plt.figure(figsize = (10,7))
plt.hist(setosa['SepalLengthCm'],label='setosa')
plt.hist(virginica['SepalLengthCm'],label='virginica')
plt.hist(versicolor['SepalLengthCm'],label='versicolor')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.distplot(setosa['SepalLengthCm'],label='setosa')
sns.distplot(virginica['SepalLengthCm'],label='virginica')
sns.distplot(versicolor['SepalLengthCm'],label='versicolor')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # SepalWidthCm

# %%
plt.figure(figsize = (10,7))
plt.hist(df['SepalWidthCm'])
plt.show()
